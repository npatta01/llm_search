# %%
import pickle
import re

# %%
# Read dictionary pkl file
with open('llm_amazon_data.pkl', 'rb') as fp:
    another_final_dict = pickle.load(fp)

# %%
another_final_dict
# Out:
# {'B00SKJPKGW': {'queries': array(['03 grand am double din radio', 'cara radio honda crx'],
#         dtype=object),
#   'title': 'Pioneer 6.8" Double DIN Touchscreen Display, Apple iPhone and Android Music Support, Bluetooth in-Dash DVD/CD AM/FM Front USB Digital Multimedia Car Stereo Receiver/Free Alphasonik Earbuds',
#   'llm': '1. "Pioneer 6.8" Bluetooth Double DIN Car Stereo for 2003 Grand Am with Free Alphasonik Earbuds"\n2. "In-Dash DVD/CD AM/FM Car Radio for Honda CRX, supports iPhone and Android Music"'},
#  '1499809093': {'queries': array(['coloring books for kids ages 2-4',
#          'coloring books for kids ages 2-4 disney'], dtype=object),
#   'title': 'Crayola My Big Coloring Book (Crayola/BuzzPop)',
#   'llm': '1. "Crayola My Big Coloring Book for preschool kids"\n2. "Crayola/BuzzPop coloring book for toddlers aged 2-4"'},
#  'B074MQFR55': {'queries': array(['cuisinart mini prep plus replacement parts',
#          'cuisinart small food processor'], dtype=object),
# ...

# %%
another_final_dict['B00EDU8HY4']

# %%
another_final_dict['B00EDU8HY4']
# Out:
# {'queries': array(['gift cards gor xbox', 'xbox one gift card'], dtype=object),
#  'title': 'Microsoft GC-Xbox LIVE EN/ES US Medialess 25 USD - Xbox 360',
#  'llm': '1. "Microsoft Xbox LIVE 25 USD gift cards"\n2. "GC-Xbox LIVE EN/ES US Medialess for Xbox 360 and Xbox One"'}

# %%
another_final_dict['B06XRKMQ55']
# Out:
# {'queries': array(['magneto wax pen', 'weed pen for smoking marijuana oil',
#         'weed pens for smoking marijuana oil', 'dry vape pen for weed',
#         'dab pens for wax and oil'], dtype=object),
#  'title': 'Saberlight Sparq Rechargeable Splash and Wind Proof Flameless Butane Free Revolutionary Plasma Beam Lighter',
#  'llm': '1. "Electric plasma lighter for smoking cannabis oil"\n2. "Rechargeable flameless lighter for use with marijuana wax pen"'}

# %%
another_final_dict['B099ZJ11CP']
# Out:
# {'queries': array(['mothernoard cpu combo', 'cpu gpu combo'], dtype=object),
#  'title': 'Micro Center AMD Ryzen 5 5600X Desktop Processor 6-core 12-Thread Up to 4.6GHz Unlocked with Wraith Stealth Cooler Bundle with MSI B550-A PRO AM4 DDR4 ATX Motherboard PCIe 4.0 M.2 USB 3.2 Gen 2',
#  'llm': '1. "AMD Ryzen 5 5600X and MSI B550-A PRO motherboard bundle"\n2. "Desktop Processor and ATX Motherboard combo"'}

# %%
another_final_dict['B099ZJ11CP']['llm'].split("\n")
# Out:
# ['1. "AMD Ryzen 5 5600X and MSI B550-A PRO motherboard bundle"',
#  '2. "Desktop Processor and ATX Motherboard combo"']

# %%
another_final_dict['B099ZJ11CP']['llm'].split("\n")[0].split(" ")
# Out:
# ['1.',
#  '"AMD',
#  'Ryzen',
#  '5',
#  '5600X',
#  'and',
#  'MSI',
#  'B550-A',
#  'PRO',
#  'motherboard',
#  'bundle"']

# %%
text=another_final_dict['B099ZJ11CP']['llm']
text
# Out:
# '1. "AMD Ryzen 5 5600X and MSI B550-A PRO motherboard bundle"\n2. "Desktop Processor and ATX Motherboard combo"'

# %%
quoted_content = re.findall(r'"(.*?)"', text)

# %%
quoted_content
# Out:
# ['AMD Ryzen 5 5600X and MSI B550-A PRO motherboard bundle',
#  'Desktop Processor and ATX Motherboard combo']

# %%
res = another_final_dict['B01ENL3Q02']

# %%
another_final_dict['B084ZQ1HYQ']
# Out:
# {'queries': array(['cliff bars chocolate chip value pack',
#         'cliff cool mint chocolate'], dtype=object),
#  'title': 'CLIF BARS with 1 Shot of Espresso - Energy Bars - Coffee Collection Variety Pack - 65 mgs of Caffeine Per Bar - Made with Organic Oats - Plant Based Food- Kosher (2.4 Ounce Breakfast Bars, 15 Count)',
#  'llm': '1. "CLIF BARS with Espresso Energy Bars Coffee Collection Variety Pack"\n2. "Organic Oats Plant Based 2.4 Ounce Breakfast Bars 15 Count"'}

# %%
text
