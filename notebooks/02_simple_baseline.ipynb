# %% [markdown]
# # About

# %% [markdown]
# This notebook uses Elastic Search to show how far a simple text retrieval can get us.
#
# [ElasticSearch](https://www.elastic.co/elasticsearch) is a search engine that supports vector search and full text search using BM25.

# %% [markdown]
# ## Import

# %%
import pandas as pd
import nltk.corpus
import nltk
import nltk.stem
import rich
import re
import code.helper
import importlib
import tqdm.auto
import code.helper_es
import json

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import streaming_bulk

# %%
import ipywidgets as widgets
from ipywidgets import interact

# %%
from IPython.display import Image, JSON
from IPython.core.display import HTML
import rich

# %% [markdown]
# ## Setup

# %% [markdown]
# check if elastic search is running

# %%
# %%bash
#
# curl -sX GET "localhost:9200/"
# Out:
# {
#   "name" : "nxb1gv6dry",
#   "cluster_name" : "elasticsearch",
#   "cluster_uuid" : "XRuFoetgQ-a5r2oh6zfbxQ",
#   "version" : {
#     "number" : "7.9.2",
#     "build_flavor" : "default",
#     "build_type" : "tar",
#     "build_hash" : "d34da0ea4a966c4e49417f2da2f244e3e97b4e6e",
#     "build_date" : "2020-09-23T00:45:33.626720Z",
#     "build_snapshot" : false,
#     "lucene_version" : "8.6.2",
#     "minimum_wire_compatibility_version" : "6.8.0",
#     "minimum_index_compatibility_version" : "6.0.0-beta1"
#   },
#   "tagline" : "You Know, for Search"
# }

# %% [markdown]
# ## Product Data

# %% [markdown]
# original data had product, query and rating.
#
# Here we will just get products

# %%
df = pd.read_parquet("../data/cleaned_input.parquet")

# %%
df.iloc[0].to_dict()
# Out:
# {'query': ' revent 80 cfm',
#  'product_id': 'B000MOO21W',
#  'relevance_label': 'Irrelevant',
#  'product_title': 'Panasonic FV-20VQ3 WhisperCeiling 190 CFM Ceiling Mounted Fan',
#  'product_description': None,
#  'product_bullet_point': 'WhisperCeiling fans feature a totally enclosed condenser motor and a double-tapered, dolphin-shaped bladed blower wheel to quietly move air\nDesigned to give you continuous, trouble-free operation for many years thanks in part to its high-quality components and permanently lubricated motors which wear at a slower pace\nDetachable adaptors, firmly secured duct ends, adjustable mounting brackets (up to 26-in), fan/motor units that detach easily from the housing and uncomplicated wiring all lend themselves to user-friendly installation\nThis Panasonic fan has a built-in damper to prevent backdraft, which helps to prevent outside air from coming through the fan\n0.35 amp',
#  'product_brand': 'Panasonic',
#  'product_color': 'White',
#  'url_product': 'https://www.amazon.com/dp/B000MOO21W',
#  'url_image': 'http://images.amazon.com/images/P/B000MOO21W.01._SCLZZZZZZZ_.jpg',
#  'query_type': 'other'}

# %%
df_product = df[['product_id','product_title','url_product','url_image']].drop_duplicates(['product_id']).reset_index(drop=True)
df_product
# Out:
#          product_id                                      product_title  \
# 0        B000MOO21W  Panasonic FV-20VQ3 WhisperCeiling 190 CFM Ceil...
# 1        B07X3Y6B1V  Homewerks 7141-80 Bathroom Fan Integrated LED ...
# 2        B07WDM7MQQ  Homewerks 7140-80 Bathroom Fan Ceiling Mount E...
# 3        B07RH6Z8KW  Delta Electronics RAD80L BreezRadiance 80 CFM ...
# 4        B07QJ7WYFQ  Panasonic FV-08VRE2 Ventilation Fan with Reces...
# ...             ...                                                ...
# 1207284  0323377092  Neurology Self-Assessment: A Companion to Brad...
# 1207285  0323287832  Bradley's Neurology in Clinical Practice, 2-Vo...
# 1207286  0198566344  Autonomic Failure: A Textbook of Clinical Diso...
# 1207287  0071845836                        The Hospital Neurology Book
# 1207288  0750674687  Pocket Companion to Neurology in Clinical Prac...
#
#                                   url_product  \
# 0        https://www.amazon.com/dp/B000MOO21W
# 1        https://www.amazon.com/dp/B07X3Y6B1V
# 2        https://www.amazon.com/dp/B07WDM7MQQ
# 3        https://www.amazon.com/dp/B07RH6Z8KW
# 4        https://www.amazon.com/dp/B07QJ7WYFQ
# ...                                       ...
# 1207284  https://www.amazon.com/dp/0323377092
# 1207285  https://www.amazon.com/dp/0323287832
# 1207286  https://www.amazon.com/dp/0198566344
# 1207287  https://www.amazon.com/dp/0071845836
# 1207288  https://www.amazon.com/dp/0750674687
#
#                                                  url_image
# 0        http://images.amazon.com/images/P/B000MOO21W.0...
# 1        http://images.amazon.com/images/P/B07X3Y6B1V.0...
# 2        http://images.amazon.com/images/P/B07WDM7MQQ.0...
# 3        http://images.amazon.com/images/P/B07RH6Z8KW.0...
# 4        http://images.amazon.com/images/P/B07QJ7WYFQ.0...
# ...                                                    ...
# 1207284  http://images.amazon.com/images/P/0323377092.0...
# 1207285  http://images.amazon.com/images/P/0323287832.0...
# 1207286  http://images.amazon.com/images/P/0198566344.0...
# 1207287  http://images.amazon.com/images/P/0071845836.0...
# 1207288  http://images.amazon.com/images/P/0750674687.0...
#
# [1207289 rows x 4 columns]

# %% [markdown]
# ## Indexing

# %% [markdown]
# simple wrapper code around elastic search

# %%
client_search = code.helper_es.SearchClient()

# %%
??client_search

# %%
# client_search.index_documents(df_product)

# %% [markdown]
# ## Analyzers

# %%
query = "adidas shoes men 15"

# %% [markdown]
# a query can be processed differently

# %%
rich.print (
    client_search.analyze(query, analyzer="stop")
)
# Out:
# {
#     'tokens': [
#         {'token': 'adidas', 'start_offset': 0, 'end_offset': 6, 'type': 'word', 'position': 0},
#         {'token': 'shoes', 'start_offset': 7, 'end_offset': 12, 'type': 'word', 'position': 1},
#         {'token': 'men', 'start_offset': 13, 'end_offset': 16, 'type': 'word', 'position': 2}
#     ]
# }

# %%
rich.print (
    client_search.analyze(query, analyzer="english")
    
)
# Out:
# {
#     'tokens': [
#         {'token': 'adida', 'start_offset': 0, 'end_offset': 6, 'type': '<ALPHANUM>', 'position': 0},
#         {'token': 'shoe', 'start_offset': 7, 'end_offset': 12, 'type': '<ALPHANUM>', 'position': 1},
#         {'token': 'men', 'start_offset': 13, 'end_offset': 16, 'type': '<ALPHANUM>', 'position': 2},
#         {'token': '15', 'start_offset': 17, 'end_offset': 19, 'type': '<NUM>', 'position': 3}
#     ]
# }

# %% [markdown]
# in the `english` analyzer, `15` token was removed

# %% [markdown]
# ## Retrieval

# %% [markdown]
# payload from elastic search

# %%
rich.print ( client_search.fetch_results(query) )
# Out:
# {
#     'took': 6,
#     'timed_out': False,
#     '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#     'hits': {
#         'total': {'value': 10000, 'relation': 'gte'},
#         'max_score': 16.438217,
#         'hits': [
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B07LBVT75L',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B07LBVT75L',
#                     'product_title': "adidas Ultraboost 19 Shoes Men's, White, Size 9",
#                     'url_product': 'https://www.amazon.com/dp/B07LBVT75L',
#                     'url_image': 'http://images.amazon.com/images/P/B07LBVT75L.01._SCLZZZZZZZ_.jpg'
#                 }
#             },
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B07LBVT3GP',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B07LBVT3GP',
#                     'product_title': "adidas Ultraboost 19 Shoes Men's, White, Size 8.5",
#                     'url_product': 'https://www.amazon.com/dp/B07LBVT3GP',
#                     'url_image': 'http://images.amazon.com/images/P/B07LBVT3GP.01._SCLZZZZZZZ_.jpg'
#                 }
#             },
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B07LBXBTW3',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B07LBXBTW3',
#                     'product_title': "adidas Ultraboost 19 Shoes Men's, White, Size 9.5",
#                     'url_product': 'https://www.amazon.com/dp/B07LBXBTW3',
#                     'url_image': 'http://images.amazon.com/images/P/B07LBXBTW3.01._SCLZZZZZZZ_.jpg'
#                 }
#             },
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B07LBXQ973',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B07LBXQ973',
#                     'product_title': "adidas Ultraboost 19 Shoes Men's, White, Size 10",
#                     'url_product': 'https://www.amazon.com/dp/B07LBXQ973',
#                     'url_image': 'http://images.amazon.com/images/P/B07LBXQ973.01._SCLZZZZZZZ_.jpg'
#                 }
#             },
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B07LBVVX8Z',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B07LBVVX8Z',
#                     'product_title': "adidas Ultraboost 19 Shoes Men's, White, Size 11",
#                     'url_product': 'https://www.amazon.com/dp/B07LBVVX8Z',
#                     'url_image': 'http://images.amazon.com/images/P/B07LBVVX8Z.01._SCLZZZZZZZ_.jpg'
#                 }
#             },
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B07TJVL9DT',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B07TJVL9DT',
#                     'product_title': "adidas Men's Pureboost B37786, Running Shoes (11.5)",
#                     'url_product': 'https://www.amazon.com/dp/B07TJVL9DT',
#                     'url_image': 'http://images.amazon.com/images/P/B07TJVL9DT.01._SCLZZZZZZZ_.jpg'
#                 }
#             },
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B07KCM8GXM',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B07KCM8GXM',
#                     'product_title': "adidas Ultraboost Shoes Men's, Black, Size 7.5",
#                     'url_product': 'https://www.amazon.com/dp/B07KCM8GXM',
#                     'url_image': 'http://images.amazon.com/images/P/B07KCM8GXM.01._SCLZZZZZZZ_.jpg'
#                 }
#             },
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B07LBLX517',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B07LBLX517',
#                     'product_title': "adidas Ultraboost 19 Shoes Men's, White, Size 10.5",
#                     'url_product': 'https://www.amazon.com/dp/B07LBLX517',
#                     'url_image': 'http://images.amazon.com/images/P/B07LBLX517.01._SCLZZZZZZZ_.jpg'
#                 }
#             },
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B07LBVLM64',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B07LBVLM64',
#                     'product_title': "adidas Ultraboost 19 Shoes Men's, White, Size 11.5",
#                     'url_product': 'https://www.amazon.com/dp/B07LBVLM64',
#                     'url_image': 'http://images.amazon.com/images/P/B07LBVLM64.01._SCLZZZZZZZ_.jpg'
#                 }
#             },
#             {
#                 '_index': 'products',
#                 '_type': '_doc',
#                 '_id': 'B08YCLGCCB',
#                 '_score': 16.438217,
#                 '_source': {
#                     'product_id': 'B08YCLGCCB',
#                     'product_title': "adidas Supernova Shoes Men's, Orange, Size 7.5",
#                     'url_product': 'https://www.amazon.com/dp/B08YCLGCCB',
#                     'url_image': 'http://images.amazon.com/images/P/B08YCLGCCB.01._SCLZZZZZZZ_.jpg'
#                 }
#             }
#         ]
#     }
# }

# %%
interesting_queries = json.load(open("../data/possible_queries.txt"))

# %% [markdown]
# resutls fetched by elastic search bm25

# %%
@interact
def interact_find_results(query=interesting_queries):
    code.helper.find_results(query ,df, show_ground_truth=False, num_hits=20 )
# Out:
# interactive(children=(Dropdown(description='query', options=('airpod case cute', 'adidas shoes men 15', 'norel…

# %%
interesting_queries
# Out:
# ['ps4 for under 100',
#  'seroma treatment',
#  'streptocarpella',
#  'trastes kawaii',
#  'turbuhaler',
#  '$1 dollar toys not fidgets',
#  '$1 million that look real but that is not it',
#  '$10 stuff not books',
#  '$100 things that are not electronics',
#  '$4 worthy items not books',
#  '$80 golf cart without roof',
#  "'freeze dryer' machine not dehydrator",
#  '.3 cc syringe without needle',
#  '/ machine wash low bleach iron do not dry clean. suggested',
#  '0.9%sodium chloride without any preservatives',
#  '1 cant believe its not butter and herb',
#  '1/8” x 1” neoprene foam without adhesive',
#  'black latex gloves not nitrile',
#  'christianity without the cross',
#  'exercise without exercise',
#  'freeze dryer machine not dehydrator',
#  "gnc women's prenatal formula without iron",
#  'instax mini 11 accessories kit without camera',
#  'laptop not chromebook',
#  'microphone without headset',
#  'mindfulness without the bells and beads',
#  'nutrients to age without senility',
#  'I want to get fancier one than the laptop I had. I think I want one of the ones with a touchscreen that folds in different ways',
#  'I would like a laptop with a big screen, touch screen if possible but not too expensive. ',
#  'I would purchase a laptop with good processing power, a RAM of above 10GB, a good video card, and good battery power.',
#  'Something that’s lightweight to carry and can be used to surf the internet and use Microsoft Office',
#  "ideally something with 8gb of ram, probably a windows laptop around £400 as in my experience that's what you can rely on and macs are too expensive.",
#  '1ml ceramic refillable vape cartridges',
#  '3d printing pen age 10',
#  '5x108 fusion spacer',
#  'accessories to make my nails strong',
#  'adidas shoes men 15',
#  'adrenaline bbq',
#  'aesop parsley seed oil 100ml',
#  'aesthetic shirts for teenage girls under 5 dollars',
#  'aforama',
#  'african montessori',
#  'airoma',
#  'airpod case cute',
#  'airport face mask kids',
#  'antibacterial wipes for rear end',
#  'aphrodisiac',
#  'applied phonetics workbook']

# %% [markdown]
# try your own queries

# %%
query = "airpod case cute"  # X


query = "adidas shoes men 15" # X


query = "adrenaline bbq"

query = "laptop not chromebook"

query = "compression socks women"

query = "dresses for women party wedding"

query = "Maxi Dresses"

query = "snow boots for women"
 
query ="gifts for men" # X relevancy

query = "digital alarm clock with usb port"

query = "norelco shavers for men" # X  relevancy


query = "salas para casa sofas baratos"


query = "jumpers for ladies"

query = "sweaters for women"

# %%
code.helper.find_results(query ,df, show_ground_truth=False , num_hits=50)
# Out:
# {
#     'query': 'sweaters for women',
#     'num_records_with_ratings': 50,
#     'num_records': 50,
#     'query_type': 'other',
#     'parsed_tokens': {
#         'tokens': [
#             {'token': 'sweaters', 'start_offset': 0, 'end_offset': 8, 'type': 'word', 'position': 0},
#             {'token': 'women', 'start_offset': 13, 'end_offset': 18, 'type': 'word', 'position': 2}
#         ]
#     }
# }
#     <h2>Query: sweaters for women </h2>
# <div style="display: flex; flex-wrap: wrap;">
#         <div style="margin: 10px; padding: 10px; border: 1px solid #ddd; border-radius: 8px; width: 200px;">
#             <img src="http://images.amazon.com/images/P/B07L9ZJS9L.01._SCLZZZZZZZ_.jpg" alt="GOLDSTITCH Heart Knitted Pullover Sweaters Long Sleeve Crewneck Cute Sweaters for Women Pink" style="width:100%; height:auto; border-radius: 5px;">
#             <h5><a href="https://www.amazon.com/dp/B07L9ZJS9L" target="_blank">GOLDSTITCH Heart Knitted Pullover Sweaters Long Sleeve Crewneck Cute Sweaters for Women Pink</a></h5>
#             <hr>
#             <p>Relevance: Unlabelled ❓  </p>
#             <p>Score: 13.296963  </p>
#         </div>
#
#         <div style="margin: 10px; padding: 10px; border: 1px solid #ddd; border-radius: 8px; width: 200px;">
#             <img src="http://images.amazon.com/images/P/B09J17GVZ6.01._SCLZZZZZZZ_.jpg" alt="Sweaters for Women Open Front Lightweight,Oversized Sweaters for Women,Fall Sweaters for Women 2021,Fall Clothes for Women,Womens Fleece Jackets Winter Warm Thick Shaggy Fuzzy Zip Up Hoodies Coats Outwear with Pockets" style="width:100%; height:auto; border-radius: 5px;">
#             <h5><a href="https://www.amazon.com/dp/B09J17GVZ6" target="_blank">Sweaters for Women Open Front Lightweight,Oversized Sweaters for Women,Fall Sweaters for Women 2021,Fall Clothes for Women,Womens Fleece Jackets Winter Warm Thick Shaggy Fuzzy Zip Up Hoodies Coats Outwear with Pockets</a></h5>
#             <hr>
#             <p>Relevance: Unlabelled ❓  </p>
#             <p>Score: 13.147911  </p>
#         </div>
#
#         <div style="margin: 10px; padding: 10px; border: 1px solid #ddd; border-radius: 8px; width: 200px;">
#             <img src="http://images.amazon.com/images/P/B07JGJVCN7.01._SCLZZZZZZZ_.jpg" alt="shermie Women's Pullover Sweaters Long Sleeve Crewneck Cute Heart Knitted Sweaters Grey Small" style="width:100%; height:auto; border-radius: 5px;">
#             <h5><a href="https://www.amazon.com/dp/B07JGJVCN7" target="_blank">shermie Women's Pullover Sweaters Long Sleeve Crewneck Cute Heart Knitted Sweaters Grey Small</a></h5>
#             <hr>
#             <p>Relevance: Unlabelled ❓  </p>
#             <p>Score: 12.736227  </p>
#         </div>
#
#         <div style="margin: 10px; padding: 10px; border: 1px solid #ddd; border-radius: 8px; width: 200px;">
#             <img src="http://images.amazon.com/images/P/B